# %% [markdown]
# # Eclipse Data Collection & Organization (RAG Source)
# This notebook scrapes NASA eclipse table data, parses it into structured dictionaries organized by **year** and **type**, and exports it as a JSON file for the main project to consume.

# %% [markdown]
# ## Setup and dependencies
#
# Import HTTP, parsing, and serialization libraries used in the notebook:
#
# - `requests` for downloading source pages,
# - `BeautifulSoup` for HTML parsing,
# - `re` for regex line detection,
# - `json`/`os` for export and file checks.

# %%
# ============================================================
# Setup and dependencies
# ============================================================
# Import libraries for web scraping, HTML parsing, and data export
import requests          # Download web pages
from bs4 import BeautifulSoup  # Parse HTML content
import json              # Export data to JSON format
import re                # Pattern matching for data extraction
import os                # File system operations

# %% [markdown]
# ## Fetch the source page
#
# Set the eclipse catalog URL, request the page, and parse it with BeautifulSoup. The printed title is a simple validation that the request succeeded.

# %%
# ============================================================
# Fetch the source page
# ============================================================
# Download the NASA eclipse catalog page and parse it with BeautifulSoup.
# The page contains eclipse data in fixed-width text format within <pre> tags.

URL = "https://eclipse.gsfc.nasa.gov/SEcat5/SE2001-2100.html"

# Download the page
response = requests.get(URL)
response.raise_for_status()  # Raise error if download failed
soup = BeautifulSoup(response.text, "html.parser")

# Print page title to confirm we got the right page
print("Page title:", soup.title.string if soup.title else "No title found")

# %% [markdown]
# ## Inspect page structure before parsing
#
# This quick inspection confirms whether the source page uses HTML tables or NASA-style `<pre>` blocks and previews sample lines. That determines which parsing branch to use next.

# %%
# ============================================================
# Inspect page structure
# ============================================================
# Check whether the page uses HTML tables or NASA-style <pre> blocks.
# NASA catalogs use <pre> tags with fixed-width text, so we need to
# detect which format we're dealing with before parsing.

tables = soup.find_all("table")
pre_blocks = soup.find_all("pre")

print(f"Found {len(tables)} HTML table(s)")
print(f"Found {len(pre_blocks)} <pre> block(s)\n")

# Preview HTML tables (if any have headers)
for idx, table in enumerate(tables):
    headers = [th.get_text(strip=True) for th in table.find_all("th")]
    if headers:
        print(f"  HTML Table {idx}: {headers[:10]}")

# Preview <pre> blocks — NASA catalogs use this format
for idx, pre in enumerate(pre_blocks):
    text = pre.get_text()
    lines = [l for l in text.splitlines() if l.strip()]
    print(f"\n  <pre> Block {idx}: {len(lines)} lines")
    # Show first 10 non-empty lines as preview
    for line in lines[:10]:
        print(f"    {line}")

# %% [markdown]
# ## How the parse step works
#
# This section converts raw NASA catalog text into structured rows:
#
# 1. **Collect lines**: It combines all `<pre>` blocks because NASA splits the catalog across multiple blocks.
# 2. **Detect data lines**: A regex keeps only lines that begin with `catalog_number + YYYY Mon DD`.
# 3. **Tokenize each line**: Each data line is split on whitespace into ordered fields.
# 4. **Map tokens to columns**: Fixed token positions are assigned to keys like `date`, `type`, `gamma`, `magnitude`, `latitude`, `longitude`, and `path_width_km`.
# 5. **Handle missing values safely**: Index checks (`if len(parts) > ...`) prevent crashes when optional fields are missing.
# 6. **Build `raw_rows`**: Each parsed line becomes a dictionary, then all dictionaries are collected for downstream cleaning/export.
#
# If `USE_PRE = False`, the alternate branch parses a normal HTML table instead.

# %%
# ============================================================
# Parse eclipse data from <pre> blocks
# ============================================================
# NASA catalog pages store eclipse data as fixed-width text inside <pre> tags.
# The data is spread across multiple <pre> blocks, and each line starts with
# a catalog number followed by the date.
#
# Example line format:
#   09511  2001 Jun 21  12:04:46  64  18  127  T  -p  -0.5701  1.0495  11S  3E  55  200  04m57s
#
# If your page uses an HTML table instead, set USE_PRE = False.
# ============================================================

USE_PRE = True       # True for NASA catalog pages
TABLE_INDEX = 0      # Only used if USE_PRE = False

raw_rows = []

if USE_PRE:
    # Combine all <pre> blocks — NASA splits the catalog across multiple blocks
    all_lines = []
    for pre in pre_blocks:
        all_lines.extend(pre.get_text().splitlines())

    print(f"Total lines across all <pre> blocks: {len(all_lines)}")

    # Find eclipse data lines using regex pattern
    # Pattern matches: catalog number (digits) + year + month + day
    # Example: "09511  2001 Jun 21  12:04:46 ..."
    date_pattern = re.compile(
        r'^\s*\d+\s+(\d{4})\s+(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\s+(\d{1,2})\s+'
    )

    data_lines = []
    for line in all_lines:
        if date_pattern.match(line):
            data_lines.append(line)

    print(f"Found {len(data_lines)} eclipse data lines.\n")
    print("Sample lines (first 5):")
    for line in data_lines[:5]:
        print(f"  {line}")

    # ============================================================
    # Map fixed-width columns to field names
    # ============================================================
    # After splitting on whitespace, tokens are at fixed positions:
    #   0: Catalog Number    (e.g. "09511")
    #   1: Year              (e.g. "2001")
    #   2: Month             (e.g. "Jun")
    #   3: Day               (e.g. "21")
    #   4: Time              (e.g. "12:04:46")
    #   5: ΔT                (e.g. "64")
    #   6: Luna Num          (e.g. "18")
    #   7: Saros Num         (e.g. "127")
    #   8: Eclipse Type      (e.g. "T", "A", "An", "P", "H")
    #   9: QLE               (e.g. "-p", "nn", "t-")
    #  10: Gamma             (e.g. "-0.5701")
    #  11: Ecl. Magnitude    (e.g. "1.0495")
    #  12: Latitude          (e.g. "11S")
    #  13: Longitude         (e.g. "3E")
    #  14: Sun Altitude      (e.g. "55")
    #  15: Path Width km     (e.g. "200" or "-")
    #  16: Central Duration  (e.g. "04m57s" or "-")
    # ============================================================

    for line in data_lines:
        parts = line.split()
        if len(parts) < 9:  # Skip lines that don't have enough fields
            continue

        row = {}
        row["catalog_number"]        = parts[0]
        row["date"]                  = f"{parts[1]} {parts[2]} {parts[3]}"
        row["time_greatest_eclipse"] = parts[4]
        row["delta_t"]               = parts[5]
        row["lunation_num"]          = parts[6] if len(parts) > 6 else ""
        row["saros"]                 = parts[7] if len(parts) > 7 else ""
        row["type"]                  = parts[8] if len(parts) > 8 else ""
        row["qle"]                   = parts[9] if len(parts) > 9 else ""
        row["gamma"]                 = parts[10] if len(parts) > 10 else ""
        row["magnitude"]             = parts[11] if len(parts) > 11 else ""
        row["latitude"]              = parts[12] if len(parts) > 12 else ""
        row["longitude"]             = parts[13] if len(parts) > 13 else ""
        row["sun_alt"]               = parts[14] if len(parts) > 14 else ""
        row["path_width_km"]         = parts[15] if len(parts) > 15 else ""
        row["central_duration"]      = parts[16] if len(parts) > 16 else ""

        # Geographic region is not in the data lines — NASA lists it on
        # separate linked pages per eclipse, not inline
        row["geographic_region"] = ""

        raw_rows.append(row)

    # Set headers for compatibility with later cells
    headers = list(raw_rows[0].keys()) if raw_rows else []

else:
    # Parse HTML table (for Wikipedia or other sites)
    target_table = tables[TABLE_INDEX]
    headers = [th.get_text(strip=True) for th in target_table.find_all("th")]
    for tr in target_table.find_all("tr"):
        cells = tr.find_all("td")
        if not cells:
            continue
        row_data = [cell.get_text(strip=True) for cell in cells]
        if len(row_data) == len(headers):
            raw_rows.append(dict(zip(headers, row_data)))

print(f"\n✓ Parsed {len(raw_rows)} total eclipse records.")
print(f"  Columns: {headers}\n")
# Preview first 5 records
for row in raw_rows[:5]:
    print(row)

# %% [markdown]
# ## Configure column mapping
#
# `COLUMN_MAP` defines how source columns map into the project's standard field names.
#
# If you switch data sources (or NASA changes labels), update this mapping instead of rewriting the parser.

# %%
# ============================================================
# Column mapping configuration
# ============================================================
# Maps standard field names to the actual column names in the parsed data.
# This makes it easy to switch data sources — just update the mapping
# instead of rewriting the parser.

COLUMN_MAP = {
    "date":       "date",               # Calendar date of the eclipse
    "type":       "type",               # Eclipse type (T, A, H, P, etc.)
    "location":   "geographic_region",  # Geographic region of visibility
    "magnitude":  "magnitude",          # Eclipse magnitude
    "duration":   "central_duration",   # Central duration (e.g. "04m57s")
    "saros":      "saros",              # Saros series number
}

print("Column mapping set:")
for k, v in COLUMN_MAP.items():
    print(f"  {k:12s} → {v}")

# %% [markdown]
# ## Normalize into a clean eclipse schema
#
# This section converts raw parsed rows into a consistent structure used across the project.
#
# It standardizes:
# - year extraction,
# - eclipse type labels (e.g., `T` -> `Total`),
# - location tokenization,
# - numeric magnitude parsing,
# - and preserves original row values in `_raw` for traceability.

# %%
# ============================================================
# Normalize into clean eclipse schema
# ============================================================
# Convert raw parsed rows into a consistent structure used across the project.
# This standardizes dates, expands type abbreviations, parses numeric values,
# and preserves original data in _raw for traceability.

# NASA type abbreviation → full name lookup
TYPE_LABELS = {
    "T":  "Total",
    "A":  "Annular",
    "H":  "Hybrid",
    "P":  "Partial",
    "Pb": "Partial",
    "Pe": "Partial",
    "T+": "Total",
    "T-": "Total",
    "Tm": "Total",
    "A+": "Annular",
    "A-": "Annular",
    "Am": "Annular",
    "An": "Annular",
    "As": "Annular",
    "Hm": "Hybrid",
    "H2": "Hybrid",
    "H3": "Hybrid",
}


def parse_year(date_string):
    """Extract a 4-digit year from various date formats using string parsing."""
    try:
        match = re.search(r'(-?\d{4})', date_string)
        if match:
            return int(match.group(1))
    except Exception:
        pass
    return None


def parse_locations(location_string):
    """Split location string into a list of region names."""
    if not location_string:
        return []
    # Split on common delimiters: commas, semicolons, hyphens, slashes
    parts = re.split(r'[,;/\-]', location_string)
    # Strip whitespace and drop empty strings
    return [part.strip() for part in parts if part.strip()]


def expand_type(abbrev):
    """Convert NASA eclipse type abbreviation to full name."""
    abbrev = abbrev.strip()
    return TYPE_LABELS.get(abbrev, abbrev)


# Build the clean eclipse list
eclipse_list = []

for row in raw_rows:
    eclipse = {}

    # Date & Year — extract year from date string
    raw_date = row.get(COLUMN_MAP["date"], "") if COLUMN_MAP["date"] else ""
    eclipse["date_raw"] = raw_date
    eclipse["year"] = parse_year(raw_date)

    # Eclipse Type — expand abbreviation (e.g., "T" → "Total")
    raw_type = row.get(COLUMN_MAP["type"], "Unknown") if COLUMN_MAP["type"] else "Unknown"
    eclipse["type_code"] = raw_type.strip()
    eclipse["type"] = expand_type(raw_type)

    # Location / Visibility — parse into list of regions
    raw_loc = row.get(COLUMN_MAP["location"], "") if COLUMN_MAP["location"] else ""
    eclipse["location_raw"] = raw_loc
    eclipse["locations"] = parse_locations(raw_loc)

    # Magnitude — convert to float (may be None if missing/invalid)
    mag_str = row.get(COLUMN_MAP["magnitude"], "") if COLUMN_MAP["magnitude"] else ""
    try:
        eclipse["magnitude"] = float(mag_str)
    except (ValueError, TypeError):
        eclipse["magnitude"] = None

    # Duration — keep as string (e.g., "04m57s")
    eclipse["duration"] = row.get(COLUMN_MAP["duration"], "") if COLUMN_MAP["duration"] else ""

    # Saros — keep as string
    eclipse["saros"] = row.get(COLUMN_MAP["saros"], "") if COLUMN_MAP["saros"] else ""

    # Preserve all original columns in _raw for traceability
    eclipse["_raw"] = row

    eclipse_list.append(eclipse)

print(f"✓ Built {len(eclipse_list)} structured eclipse records.\n")
print("Sample records:")
for e in eclipse_list[:5]:
    print(f"  {e['date_raw']:15s}  Type: {e['type']:10s}  Mag: {e['magnitude']}  "
          f"Saros: {e['saros']:4s}  Region: {e['location_raw'][:50]}")

# %% [markdown]
# ## Build lookup indexes
#
# Here the notebook organizes the cleaned eclipse records into two dictionaries:
#
# - `eclipses_by_year` for chronological filtering,
# - `eclipses_by_type` for type-based queries.
#
# These indexes make downstream retrieval much faster and simpler.

# %%
# ============================================================
# Build lookup indexes
# ============================================================
# Organize cleaned eclipse records into dictionaries for fast lookup:
# - eclipses_by_year: for chronological filtering
# - eclipses_by_type: for type-based queries
# These indexes make downstream retrieval much faster.

# Dictionary keyed by year
eclipses_by_year = {}
for e in eclipse_list:
    yr = e["year"]
    if yr is not None:
        eclipses_by_year.setdefault(yr, []).append(e)

# Sort years chronologically
eclipses_by_year = dict(sorted(eclipses_by_year.items()))

print("=== Eclipses by Year ===")
for year, items in eclipses_by_year.items():
    print(f"  {year}: {len(items)} eclipse(s)")

# Dictionary keyed by type
eclipses_by_type = {}
for e in eclipse_list:
    etype = e["type"].strip() if e["type"] else "Unknown"
    eclipses_by_type.setdefault(etype, []).append(e)

# Sort types alphabetically
eclipses_by_type = dict(sorted(eclipses_by_type.items()))

print("\n=== Eclipses by Type ===")
for etype, items in eclipses_by_type.items():
    print(f"  {etype}: {len(items)} eclipse(s)")

# %% [markdown]
# ## Export the final dataset
#
# This final step writes one JSON file used by the app and chatbot. The payload includes:
#
# - source metadata (`source_url`, `total_eclipses`),
# - the normalized flat list (`eclipse_list`),
# - index dictionaries for quick lookup (`by_year`, `by_type`).
#
# After saving, it prints a quick sanity check (file size and record counts).

# %%
# ============================================================
# Export to JSON
# ============================================================
# Write the final dataset to a JSON file that the chatbot and visualization
# tools can load. The payload includes source metadata, the normalized
# eclipse list, and lookup indexes for fast queries.

OUTPUT_FILE = "eclipse_data.json"

export_payload = {
    "source_url": URL,
    "total_eclipses": len(eclipse_list),
    "eclipse_list": eclipse_list,  # Main list used by all tools
    "by_year": {str(k): v for k, v in eclipses_by_year.items()},  # Year index
    "by_type": eclipses_by_type,  # Type index
}

# Write JSON file with pretty formatting
with open(OUTPUT_FILE, "w") as f:
    json.dump(export_payload, f, indent=2, default=str)

# Print summary statistics
file_size = os.path.getsize(OUTPUT_FILE)
print(f"Saved {OUTPUT_FILE}  ({file_size:,} bytes)")
print(f"  → {export_payload['total_eclipses']} eclipses")
print(f"  → {len(eclipses_by_year)} unique year(s)")
print(f"  → {len(eclipses_by_type)} unique type(s)")
print(f"\nYour main code can now load this with:")
print(f'  with open("{OUTPUT_FILE}") as f:')
print(f'      data = json.load(f)')
